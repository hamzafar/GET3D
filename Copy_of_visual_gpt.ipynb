# %% [markdown]
# <a href="https://colab.research.google.com/github/hamzafar/GET3D/blob/master/Copy_of_visual_gpt.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/microsoft/visual-chatgpt.git
# Out:
# Cloning into 'visual-chatgpt'...
# remote: Enumerating objects: 90, done.
# remote: Counting objects: 100% (53/53), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 90 (delta 38), reused 35 (delta 28), pack-reused 37
# Unpacking objects: 100% (90/90), 6.13 MiB | 2.74 MiB/s, done.

# %%
# %cd /content/visual-chatgpt
# Out:
# /content/visual-chatgpt

# %%
# %%bash
# MINICONDA_INSTALLER_SCRIPT=Miniconda3-4.5.4-Linux-x86_64.sh
# MINICONDA_PREFIX=/usr/local
# wget https://repo.continuum.io/miniconda/$MINICONDA_INSTALLER_SCRIPT
# chmod +x $MINICONDA_INSTALLER_SCRIPT
# ./$MINICONDA_INSTALLER_SCRIPT -b -f -p $MINICONDA_PREFIX

# conda install --channel defaults conda python=3.8 --yes
# conda update --channel defaults --all --yes

# %%
# import sys
# sys.path.append("/usr/local/lib/python3.8/site-packages")

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 344.0/344.0 KB 15.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.4/776.4 MB 2.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 55.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 212.8/212.8 KB 26.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 172.5/172.5 KB 22.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 737.4/737.4 KB 54.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.6/41.6 KB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.3/14.3 MB 91.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.9/26.9 MB 68.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 86.7 MB/s eta 0:00:00
# ...

# %%
# !pip install pytorch_lightning
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 827.8/827.8 KB 33.1 MB/s eta 0:00:00
# ...

# %%
# !bash download.sh
# Out:
# Cloning into 'ControlNet'...
# remote: Enumerating objects: 1264, done.
# remote: Counting objects: 100% (12/12), done.
# remote: Compressing objects: 100% (12/12), done.
# remote: Total 1264 (delta 6), reused 5 (delta 0), pack-reused 1252
# Receiving objects: 100% (1264/1264), 122.36 MiB | 27.60 MiB/s, done.
# Resolving deltas: 100% (548/548), done.

# %%
# %env OPENAI_API_KEY=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
# Out:
# env: OPENAI_API_KEY=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

# %%
# !mkdir ./image
